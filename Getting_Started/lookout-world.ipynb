# %% [markdown]
# # Lookout World
#
# Test jupyter notebook with `Pandas` and spreadsheet reading
#
# [more info on pandas here](https://pandas.pydata.org/)

# %%
import pandas as pd
import json

# %%
alloc = pd.read_csv('test-allocations.csv')
alloc
# Out:
#        CATEGORY   CATEGORY_METHOD          CODE  \
# 0  Aasset Class      Global Bonds  IE00BPT2BQ43
# 1  Aasset Class      Global Bonds  IE00BPT2BZ34
# 2  Aasset Class          UK Bonds  GB00BPN5P451
# 3  Aasset Class          UK Bonds  IE00BPT2BS66
# 4  Aasset Class          UK Bonds  IE00BPT2BV95
# 5  Aasset Class   Global Equities  GB00BG0QP604
# 6  Aasset Class       UK Equities  GB00B7C44X99
# 7  Aasset Class  Emerging Markets  GB00BG0QP489
# 8  Aasset Class              Cash           GBP
#
#                                            FUND_NAME  ALLOCATION
# 0  Vanguard Global Bond Index Fund GBP Hedged Acc...          60
# 1  Vanguard Global Short-Term Bond Index Fund GBP...          40
# 2  Vanguard U.K. Inflation-Linked Gilt Index Fund...          20
# 3  Vanguard U.K. Government Bond Index Fund GBP A...          20
# 4  Vanguard U.K. Investment Grade Bond Index Fund...          60
# 5    Legal & General International Index Trust C Acc         100
# ...

# %%
alloc_json = alloc.to_json(orient='records', indent=4)
print(alloc_json)
# Out:
# [
#     {
#         "CATEGORY":"Aasset Class",
#         "CATEGORY_METHOD":"Global Bonds",
#         "CODE":"IE00BPT2BQ43",
#         "FUND_NAME":"Vanguard Global Bond Index Fund GBP Hedged Acc Inst",
#         "ALLOCATION":60
#     },
#     {
#         "CATEGORY":"Aasset Class",
#         "CATEGORY_METHOD":"Global Bonds",
#         "CODE":"IE00BPT2BZ34",
#         "FUND_NAME":"Vanguard Global Short-Term Bond Index Fund GBP Hedged Acc Institutional Plus",
#         "ALLOCATION":40
#     },
#     {
#         "CATEGORY":"Aasset Class",
#         "CATEGORY_METHOD":"UK Bonds",
#         "CODE":"GB00BPN5P451",
#         "FUND_NAME":"Vanguard U.K. Inflation-Linked Gilt Index Fund INSTITUTIONAL PLUS GBP ACC",
#         "ALLOCATION":20
#     },
#     {
#         "CATEGORY":"Aasset Class",
#         "CATEGORY_METHOD":"UK Bonds",
#         "CODE":"IE00BPT2BS66",
#         "FUND_NAME":"Vanguard U.K. Government Bond Index Fund GBP Acc Inst Plus",
#         "ALLOCATION":20
#     },
#     {
# ...
