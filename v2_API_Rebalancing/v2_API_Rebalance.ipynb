# %% [markdown]
# # v2 Rebalancing API Example
#
# This is a replication of Binu's Postman Env and Collection.

# %%
import pandas as pd
import json
import requests

# %% [markdown]
# ### Step 1: Setup Request Environment
# Reading postman environment provided by Binu

# %%
with open('V2 Rebalance API.postman_environment.json', 'r') as env_json:
    env_data = json.load(env_json)

env = {}
for row in env_data.get("values"):
    env[row.get('key')] = row.get('value')

env
# Out:
# {'admin-apiKey': 'JUF^fqRW7ao9X&SY9^n%BGc',
#  'URL': 'https://fsalgoapims.azure-api.net/',
#  'apiKey': '6177321eac992341d1ad0823a07e76bfc4ee6909db120e377ea303fdc216756c',
#  'Ocp-Apim-Subscription-Key': 'fa061f8aeb454788ac54dfaea685fdaa',
#  'azureUrl': 'https://fsalgoapims.azure-api.net'}

# %% [markdown]
# ### Step 2: Get Portfolio Rebalance Data
# Again, from Binu's PostMan config but could be the API request body from CPS Reports

# %%
coll_file = 'V2 Rebalancing API.postman_collection.json'
with open(coll_file, 'r') as req_json:
    req_data = json.load(req_json)

rebal_req_body = dict(json.loads(req_data.get('item')[0].get('request').get('body').get('raw')))
rebal_req_body.keys()
# Out:
# dict_keys(['ExchangeRates', 'HierarchicalModelPortfolio', 'InvestmentDetails', 'PortfolioHoldings', 'PortfolioMandateRules', 'RequestOptions', 'SimpleModelPortfolios'])

# %%
rebal_req_body.get('PortfolioHoldings').get('Accounts')[0]
# Out:
# {'AccountID': 'ACC1',
#  'AccountName': '503',
#  'AdvancedOptions': {'AccountType': '66c08dc0-4871-48cf-9f62-bd72a060119f',
#   'BuyPriority': 0,
#   'SellPriority': 0,
#   'CashAdjustmentCalculationCurrencyValue': -50000},
#  'CashHoldings': [{'Balance': 10000,
#    'CashAccountName': 'USD CASH',
#    'CurrencyCode': 'USD',
#    'Reserved': 0},
#   {'Balance': 20000,
#    'CashAccountName': 'AUD CASH',
#    'CurrencyCode': 'AUD',
#    'Reserved': 0}],
#  'Investments': [{'InvestmentId': '9db84185-16d8-4610-a215-04057ee361d4',
#    'Parcels': [{'CostBase': 2433.53,
#      'ParcelId': 1,
#      'PurchaseDate': '2024-12-11T00:00:00',
#      'PurchasePrice': 2433.53,
#      'Quantity': 10,
#      'Reserved': 0}]},
#   {'InvestmentId': '0b3366c4-06fa-4101-a5dc-f6d2613a5258',
#    'Parcels': [{'CostBase': 5.63,
#      'ParcelId': 1,
#      'PurchaseDate': '2024-12-11T00:00:00',
#      'PurchasePrice': 5.63,
#      'Quantity': 5000,
#      'Reserved': 0}]},
#   {'InvestmentId': '0c3ba234-06d4-4a5b-9f4a-abbfb813a583',
#    'Parcels': [{'CostBase': 250,
#      'ParcelId': 1,
#      'PurchaseDate': '2024-12-11T00:00:00',
#      'PurchasePrice': 250,
#      'Quantity': 100,
#      'Reserved': 0}]},
#   {'InvestmentId': '844a328b-9863-4dc0-8129-78f59f8754f8',
#    'Parcels': [{'CostBase': 10,
#      'ParcelId': 1,
#      'PurchaseDate': '2024-12-11T00:00:00',
#      'PurchasePrice': 10,
#      'Quantity': 2000,
#      'Reserved': 0}]}]}

# %% [markdown]
# ### Step 3: Make the Request
# With the body and auth tokens, we can now send the data to the rebal engine

# %%
headers = {
    'Content-Type': 'application/json',
    'x-fsee-apikey': env.get('apiKey'),
    'Ocp-Apim-Subscription-Key': env.get('Ocp-Apim-Subscription-Key')
}

rebal_url = 'https://fsalgoapims.azure-api.net/rebalance'
response = requests.post(rebal_url, json=rebal_req_body, headers=headers)

response
# Out:
# <Response [200]>

# %% [markdown]
# Once we have the response data, we can access the data as a dictionary and do a variety of wonderful pythonic things with it, such as look at the keys

# %%
rebal_data = response.json()
rebal_data.keys()
# Out:
# dict_keys(['responseId', 'requestId', 'clientRequestId', 'calculationCurrencyMovement', 'cashAccountsMovements', 'investmentHoldingsMovements', 'errors', 'diagnostics'])

# %% [markdown]
# We could access all the data or we could slice it and look at something that is more interesting to analysts.
#
# In the below example we will look at the `investmentHoldingsMovements`

# %%
rebal_data.get('investmentHoldingsMovements')
# Out:
# [{'investmentId': '9db84185-16d8-4610-a215-04057ee361d4',
#   'investmentCode': 'GOOG',
#   'marketCode': 'NASDAQ',
#   'price': 2000,
#   'investmentCurrency': 'USD',
#   'purchasePrice': 0,
#   'costBase': 2112.396667,
#   'realisedGain': 0,
#   'unrealisedGain': 0,
#   'investmentMovement': {'type': 'Sell',
#    'units': -30,
#    'value': 87000.0,
#    'brokerage': 0,
#    'parcelOrders': [{'accountId': 'ACC1',
#      'parcelId': 1,
#      'purchaseDate': '2024-12-11T00:00:00',
#      'purchasePrice': 2433.53,
#      'costBase': 2433.53,
#      'realisedGain': None,
#      'unrealisedGain': None,
#      'orderType': 'Sell',
#      'orderUnits': -10,
#      'orderValue': 29000.0,
#      'orderBrokerage': 0.0,
#      'currentUnits': 10,
#      'currentValue': 29000.0,
#      'currentPercentage': 0.119959,
#      'finalUnits': 0,
#      'finalValue': 0.0,
#      'finalPercentage': 0,
#      'reservedUnits': None},
#     {'accountId': 'ACC3',
#      'parcelId': 1,
#      'purchaseDate': '2025-01-20T00:00:00',
#      'purchasePrice': 2000,
#      'costBase': 2000,
#      'realisedGain': None,
#      'unrealisedGain': None,
#      'orderType': 'Sell',
#      'orderUnits': -20,
#      'orderValue': 58000.0,
#      'orderBrokerage': 0.0,
#      'currentUnits': 20,
#      'currentValue': 58000.0,
#      'currentPercentage': 0.239917,
#      'finalUnits': 0,
#      'finalValue': 0.0,
#      'finalPercentage': 0,
#      'reservedUnits': None}]},
#   'targetUnits': 0,
#   'targetValue': 0,
#   'targetPercentage': 0,
#   'currentUnits': 30,
#   'currentValue': 87000.0,
#   'currentPercentage': 0.359876,
#   'finalUnits': 0,
#   'finalValue': 0.0,
#   'finalPercentage': 0,
#   'reservedUnits': None},
#  {'investmentId': '0b3366c4-06fa-4101-a5dc-f6d2613a5258',
#   'investmentCode': '360',
#   'marketCode': 'ASX',
#   'price': 5,
#   'investmentCurrency': 'AUD',
#   'purchasePrice': 0,
#   'costBase': 5.63,
#   'realisedGain': 0,
#   'unrealisedGain': 0,
#   'investmentMovement': {'type': 'Buy',
#    'units': 10340,
#    'value': -51700,
#    'brokerage': 0,
#    'parcelOrders': [{'accountId': 'ACC1',
#      'parcelId': 2,
#      'purchaseDate': None,
#      'purchasePrice': None,
#      'costBase': 0,
#      'realisedGain': None,
#      'unrealisedGain': None,
#      'orderType': 'Buy',
#      'orderUnits': 5822,
#      'orderValue': -29110,
#      'orderBrokerage': 0,
#      'currentUnits': 0,
#      'currentValue': 0,
#      'currentPercentage': 0,
#      'finalUnits': 5822,
#      'finalValue': 29110,
#      'finalPercentage': 0.120414,
#      'reservedUnits': None},
#     {'accountId': 'ACC3',
#      'parcelId': 1,
#      'purchaseDate': None,
#      'purchasePrice': None,
#      'costBase': 0,
#      'realisedGain': None,
#      'unrealisedGain': None,
#      'orderType': 'Buy',
#      'orderUnits': 4518,
#      'orderValue': -22590,
#      'orderBrokerage': 0,
#      'currentUnits': 0,
#      'currentValue': 0,
#      'currentPercentage': 0,
#      'finalUnits': 4518,
#      'finalValue': 22590,
#      'finalPercentage': 0.093444,
#      'reservedUnits': None}]},
#   'targetUnits': 19340,
#   'targetValue': 96700.0,
#   'targetPercentage': 0.4,
#   'currentUnits': 9000,
#   'currentValue': 45000,
#   'currentPercentage': 0.186143,
#   'finalUnits': 19340,
#   'finalValue': 96700,
#   'finalPercentage': 0.4,
#   'reservedUnits': None},
#  {'investmentId': '0c3ba234-06d4-4a5b-9f4a-abbfb813a583',
#   'investmentCode': 'MSFT',
#   'marketCode': 'NASDAQ',
#   'price': 250,
#   'investmentCurrency': 'USD',
#   'purchasePrice': 0,
#   'costBase': 250,
#   'realisedGain': 0,
#   'unrealisedGain': 0,
#   'investmentMovement': {'type': 'Buy',
#    'units': -7,
#    'value': 2537.5,
#    'brokerage': 0,
#    'parcelOrders': [{'accountId': 'ACC1',
#      'parcelId': 1,
#      'purchaseDate': '2024-12-11T00:00:00',
#      'purchasePrice': 250,
#      'costBase': 250,
#      'realisedGain': None,
#      'unrealisedGain': None,
#      'orderType': 'Sell',
#      'orderUnits': -28,
#      'orderValue': 10150.0,
#      'orderBrokerage': 0.0,
#      'currentUnits': 100,
#      'currentValue': 36250.0,
#      'currentPercentage': 0.149948,
#      'finalUnits': 72,
#      'finalValue': 26100.0,
#      'finalPercentage': 0.107963,
#      'reservedUnits': None},
#     {'accountId': 'ACC3',
#      'parcelId': 1,
#      'purchaseDate': None,
#      'purchasePrice': None,
#      'costBase': 0,
#      'realisedGain': None,
#      'unrealisedGain': None,
#      'orderType': 'Buy',
#      'orderUnits': 21,
#      'orderValue': -7612.5,
#      'orderBrokerage': 0.0,
#      'currentUnits': 0,
#      'currentValue': 0.0,
#      'currentPercentage': 0,
#      'finalUnits': 21,
#      'finalValue': 7612.5,
#      'finalPercentage': 0.031489,
#      'reservedUnits': None}]},
#   'targetUnits': 133,
#   'targetValue': 48350.0,
#   'targetPercentage': 0.2,
#   'currentUnits': 140,
#   'currentValue': 50750.0,
#   'currentPercentage': 0.209928,
#   'finalUnits': 133,
#   'finalValue': 48212.5,
#   'finalPercentage': 0.199431,
#   'reservedUnits': None},
#  {'investmentId': '844a328b-9863-4dc0-8129-78f59f8754f8',
#   'investmentCode': 'TNE',
#   'marketCode': 'ASX',
#   'price': 10,
#   'investmentCurrency': 'AUD',
#   'purchasePrice': 0,
#   'costBase': 10,
#   'realisedGain': 0,
#   'unrealisedGain': 0,
#   'investmentMovement': {'type': 'Buy',
#    'units': 3252,
#    'value': -32520,
#    'brokerage': 0,
#    'parcelOrders': [{'accountId': 'ACC1',
#      'parcelId': 1,
#      'purchaseDate': '2024-12-11T00:00:00',
#      'purchasePrice': 10,
#      'costBase': 10,
#      'realisedGain': None,
#      'unrealisedGain': None,
#      'orderType': 'Sell',
#      'orderUnits': -546,
#      'orderValue': 5460,
#      'orderBrokerage': 0,
#      'currentUnits': 2000,
#      'currentValue': 20000,
#      'currentPercentage': 0.08273,
#      'finalUnits': 1454,
#      'finalValue': 14540,
#      'finalPercentage': 0.060145,
#      'reservedUnits': None},
#     {'accountId': 'ACC3',
#      'parcelId': 2,
#      'purchaseDate': None,
#      'purchasePrice': None,
#      'costBase': 0,
#      'realisedGain': None,
#      'unrealisedGain': None,
#      'orderType': 'Buy',
#      'orderUnits': 3798,
#      'orderValue': -37980,
#      'orderBrokerage': 0,
#      'currentUnits': 0,
#      'currentValue': 0,
#      'currentPercentage': 0,
#      'finalUnits': 3798,
#      'finalValue': 37980,
#      'finalPercentage': 0.157104,
#      'reservedUnits': None}]},
#   'targetUnits': 7252,
#   'targetValue': 72525.0,
#   'targetPercentage': 0.3,
#   'currentUnits': 4000,
#   'currentValue': 40000,
#   'currentPercentage': 0.16546,
#   'finalUnits': 7252,
#   'finalValue': 72520,
#   'finalPercentage': 0.299979,
#   'reservedUnits': None}]

# %% [markdown]
# What we will mostly find is that analysts will want to use the `Pandas` library to look at the data in Table.

# %%
rebal_df = pd.DataFrame(rebal_data.get('investmentHoldingsMovements'))
rebal_df
# Out:
#                            investmentId investmentCode marketCode  price  \
# 0  9db84185-16d8-4610-a215-04057ee361d4           GOOG     NASDAQ   2000
# 1  0b3366c4-06fa-4101-a5dc-f6d2613a5258            360        ASX      5
# 2  0c3ba234-06d4-4a5b-9f4a-abbfb813a583           MSFT     NASDAQ    250
# 3  844a328b-9863-4dc0-8129-78f59f8754f8            TNE        ASX     10
#
#   investmentCurrency  purchasePrice     costBase  realisedGain  \
# 0                USD              0  2112.396667             0
# 1                AUD              0     5.630000             0
# 2                USD              0   250.000000             0
# 3                AUD              0    10.000000             0
#
#    unrealisedGain                                 investmentMovement  \
# 0               0  {'type': 'Sell', 'units': -30, 'value': 87000....
# 1               0  {'type': 'Buy', 'units': 10340, 'value': -5170...
# 2               0  {'type': 'Buy', 'units': -7, 'value': 2537.5, ...
# 3               0  {'type': 'Buy', 'units': 3252, 'value': -32520...
#
#    targetUnits  targetValue  targetPercentage  currentUnits  currentValue  \
# 0            0          0.0               0.0            30       87000.0
# 1        19340      96700.0               0.4          9000       45000.0
# 2          133      48350.0               0.2           140       50750.0
# 3         7252      72525.0               0.3          4000       40000.0
#
#    currentPercentage  finalUnits  finalValue  finalPercentage reservedUnits
# 0           0.359876           0         0.0         0.000000          None
# 1           0.186143       19340     96700.0         0.400000          None
# 2           0.209928         133     48212.5         0.199431          None
# 3           0.165460        7252     72520.0         0.299979          None
